# %% [markdown]
# # 2026-08-25

# %% [markdown]
# ## State

# %% [markdown]
# Stage 1: five cities banked, all Variant A, all V_star positive-definite, qAIC 27,047–28,993 — and now on trial (§11.6). Stage 2: two pools live — top-down (stage2_k5_v2, §7.5 pca_cma scores) and bottom-up (stage2_bu, §11.3, REML converged, 20 coefficients, df.residual −10, reshape proven against fitted() to zero). Bottom-up rotation (§11.1): prcomp on the 21,111 × 17 stack, cum var 86.9% split 0.321/0.289/0.259, PC1 city order matches top-down. Native-score map (§11.4): pearson −0.946, amplitude 2.76× — flip survives the seamless build. Diagnosis (§11.5): reshape/pairing/predictors acquitted, reversal isolated to the outcome side. Sign branch run (§11.6, 2026-08-21): each city's own curve at its own p90 knot vs mean truth, Spearman −0.9, anti-track — MTL highest truth (0.608) lowest curve (−0.851, RR 0.43 at heat, impossible under the DGP). Branch fired: Stage 1 on trial, reversal born before pooling. Criterion 3 rescored on the bottom-up loadings (§11.7): C3 = 0.849 (best |cor| per true factor 0.947/0.801/0.800, permutation F1→PC2, F2→PC1, F3→PC3), replaces the v1 0.731 — after one fake pass at exactly 1.000 off a nonexistent $rotation slot. Two reflexes minted: knots carry a quantile label, unname() before name lookup; exact-diagonal 1.000 is a mirror not a match, guard the extraction with is.matrix. Banked saves_eod_2026-08-21: tab1_p90_sign, loadings_bu, c3_bu, pca_da_var — everything else in §11 regenerates from 07-22. SSOT: §0 replaced with the lean restore (session RData in, 06-25 out — contents duplicated in 07-22), §11.6 ticket resolved to pipeline, §11.7 added, fit_stage1-×3 flag in §4 preamble. Dirty notebook: 2026-08-21_DirtyR_N5-sign-branch-C3. Calgary, output stack, choropleth unrun — parked by the branch rule and the clock.

# %% [markdown]
# ## Open

# %% [markdown]
# The sign inversion is now inside Stage 1 or the per-city simulation — §11.6's anti-track (−0.9) rules out everything downstream of the five city curves. Blocked on nothing. Unblocks at the resume point: simulate one city, fit, read the curve's sign at its own p90 directly against base_log_rr — the DGP is positive at heat, so a faithful fit cannot print MTL's −0.85; whichever step first disagrees with base_log_rr owns the flip. Amplitude 2.76×: recorded, not tuned, resolves after the sign. Choropleth: gated on the sign — a map from inverted curves is a receipt of the wrong thing. Calgary is the sixth city, blocked on the Prairies DA-level Census Profile GEONO (006_Prairies, link banked, ~427 MB) — stream-filter to Calgary CMA, §9.7b logic at seed_offset 825; download is the manual-fight risk, budget a full block. Overhaul, mine: demote the v1 spine (§5, §6.5, §7.3–7.4, §9.6) plus §10's top-down spine to provenance, fix duplicate §4 numbering, drop v1 stage2.rds from §0, resolve fit_stage1 ×3 in fns.R (flagged §4, 2026-08-21), fns.R generated from the SSOT not hand-synced, then GitHub as the real architecture. save_to_drive tars /content/saves_eod without emptying it — unlink(recursive = TRUE) above dir.create; second edit: bank argvar alone, drop cb_template from banked Stage 1 results. simulate_counts returns 10 loose columns; refactor to the asserted schema. df.residual −10 at K=5 — check against mixmeta's documentation before Criterion 4 is claimed either way. Project-side fns.R and README pre-date v2 and §11 both; README State section v1-stale end to end. Settled file + backlog file: ruled 08-12, still not created.

# %% [markdown]
# ## Shelf
#
# vDL credentials — arrived 07-15 — real CVSD mortality replaces the simulated DGP — terms unread, expires before first data request. vDL login — reread Éric's email for what's linked (product, vintage, level); codebook → geography level; folder filenames → study period; temperature file docs → linkage method; docs → software-request channel. Read-only, nothing filed; Monday files the packages ticket + import request, two clocks in parallel. Virtual machine — parked 07-29 — package availability check for dlnm/gnm/data.table — no expiry. mixmeta documentation — 07-22 — the df.residual and Q/I² accounting at K=5 — before Criterion 4 is claimed. Table 1 E&W shape — cleared by Éric 08-12 — bank the wording for the Methods appendix. DRAC SLURM draft — deferred across sessions, still parked.
